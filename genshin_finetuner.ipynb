# %% [markdown]
# # Genshin Impact! Fine-tuning CLIP for anime search
#
# Today let's build a search-anime system. We will use text as our query and get images as result. For this we would usually need to manually annotate the image with some tags, often referred to as `TBIR` (Text/Tag-based Image Retrieval). And for this example, we will use [OpenAI CLIP](https://github.com/openai/CLIP).
#
# CLIP is a powerful embedding model that outputs the similarity between text and images. And while it delivers great results, its zero-shot capability needs to be improved on domain data.
#
# We'll build our search system using [Jina](https://docs.jina.ai/) with CLIP as the encoder. But since we already said that CLIP needs to improve its zero-shot capabilities, we will fine-tune our model with [Finetuner](https://github.com/jina-ai/finetuner). But we want to make sure fine-tuning is improving our results, so to examine the effectiveness of the original CLIP on an anime dataset, we'll fine-tune the CLIP model with half of the dataset, then see if the search results improve.
#
# ## The data
#
# ![Albedo](https://storage.googleapis.com/kaggle-datasets-images/2071434/3438247/7cae3f8ae6d0e09f93df60bea523f7aa/dataset-cover.jpg?t=2022-04-10-16-04-06)
#
# The dataset is a public dataset from [Kaggle](https://www.kaggle.com/datasets/just1ce5/genshin-impact-characters-dataset) from the popular game [Genshin Impact](https://genshin.hoyoverse.com/pc-launcher/?utm_source=EU_google_DE_search_20220720&mhy_trace_channel=ga_channel&new=1&gclid=Cj0KCQjwz96WBhC8ARIsAATR250k1qTcxh8i1saR-tXXDt3SFlk2XGV93oMz3DZEF8T7Zs8RrTxT0LIaAgFUEALw_wcB#/GI008). It contatins five categories: four Genshin characters and one for 'None of them'
#
# - Albedo
# - Ayaka
# - Hu Tao
# - Kokomi
# - Nether (None of these characters)
#
# Each character has 100 images, for a total of 500 images. We'll fine-tune `CLIP` with only 250 images.
#
# ## Download data and install dependencies

# %%
# !pip install -U "finetuner[full]" # finetuner-full will install ML libraries such as torchvision and transformers

# !pip install gdown
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting finetuner[full]
#   Downloading finetuner-0.8.1.tar.gz (39 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting docarray[common]<0.30.0 (from finetuner[full])
#   Downloading docarray-0.21.1.tar.gz (658 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 2.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting finetuner-stubs==0.13.10 (from finetuner[full])
#   Downloading finetuner_stubs-0.13.10-py3-none-any.whl (16 kB)
# Collecting finetuner-commons==0.13.10 (from finetuner[full])
#   Downloading finetuner_commons-0.13.10-py3-none-any.whl (39 kB)
# Collecting jina-hubble-sdk==0.33.1 (from finetuner[full])
#   Downloading jina_hubble_sdk-0.33.1-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 3.2 MB/s eta 0:00:00
# Collecting trimesh==3.16.4 (from finetuner[full])
#   Downloading trimesh-3.16.4-py3-none-any.whl (663 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 kB 6.3 MB/s eta 0:00:00
# Collecting onnx>1.11.0 (from finetuner-commons==0.13.10->finetuner[full])
#   Downloading onnx-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 34.3 MB/s eta 0:00:00
# Collecting onnxruntime>1.11.1 (from finetuner-commons==0.13.10->finetuner[full])
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 58.5 MB/s eta 0:00:00
# Collecting open-clip-torch==2.20.0 (from finetuner-commons==0.13.10->finetuner[full])
#   Downloading open_clip_torch-2.20.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 44.7 MB/s eta 0:00:00
# Requirement already satisfied: rich>=12.4.4 in /usr/local/lib/python3.10/dist-packages (from finetuner-commons==0.13.10->finetuner[full]) (13.4.2)
# Requirement already satisfied: torchvision~=0.15.2 in /usr/local/lib/python3.10/dist-packages (from finetuner-commons==0.13.10->finetuner[full]) (0.15.2+cu118)
# Requirement already satisfied: torch~=2.0.1 in /usr/local/lib/python3.10/dist-packages (from finetuner-commons==0.13.10->finetuner[full]) (2.0.1+cu118)
# Collecting transformers==4.20.1 (from finetuner-commons==0.13.10->finetuner[full])
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 68.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic~=1.10.11 in /usr/local/lib/python3.10/dist-packages (from finetuner-stubs==0.13.10->finetuner[full]) (1.10.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (2.27.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (3.8.5)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (4.6.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (3.12.2)
# Collecting pathspec (from jina-hubble-sdk==0.33.1->finetuner[full])
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Collecting docker (from jina-hubble-sdk==0.33.1->finetuner[full])
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (6.0.1)
# Collecting python-jose (from jina-hubble-sdk==0.33.1->finetuner[full])
#   Downloading python_jose-3.3.0-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from trimesh==3.16.4->finetuner[full]) (1.22.4)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (2022.10.31)
# Collecting ftfy (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (4.65.0)
# Collecting huggingface-hub (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.0 MB/s eta 0:00:00
# Collecting sentencepiece (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<4 in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (3.20.3)
# Collecting timm (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 72.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.20.1->finetuner-commons==0.13.10->finetuner[full]) (23.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1 (from transformers==4.20.1->finetuner-commons==0.13.10->finetuner[full])
#   Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 88.2 MB/s eta 0:00:00
# Collecting lz4 (from docarray[common]<0.30.0->finetuner[full])
#   Downloading lz4-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from docarray[common]<0.30.0->finetuner[full]) (3.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from docarray[common]<0.30.0->finetuner[full]) (9.4.0)
# Collecting fastapi (from docarray[common]<0.30.0->finetuner[full])
#   Downloading fastapi-0.100.1-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 8.9 MB/s eta 0:00:00
# Collecting uvicorn (from docarray[common]<0.30.0->finetuner[full])
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx>1.11.0->finetuner-commons==0.13.10->finetuner[full]) (4.7.1)
# Collecting coloredlogs (from onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full]) (23.5.26)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full]) (1.11.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.4.4->finetuner-commons==0.13.10->finetuner[full]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.4.4->finetuner-commons==0.13.10->finetuner[full]) (2.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (16.0.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.3.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker->jina-hubble-sdk==0.33.1->finetuner[full]) (1.26.16)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker->jina-hubble-sdk==0.33.1->finetuner[full]) (1.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->jina-hubble-sdk==0.33.1->finetuner[full]) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->jina-hubble-sdk==0.33.1->finetuner[full]) (3.4)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->docarray[common]<0.30.0->finetuner[full])
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (2.8.2)
# Collecting ecdsa!=0.15 (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full])
#   Downloading ecdsa-0.18.0-py2.py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (4.9)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (0.5.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn->docarray[common]<0.30.0->finetuner[full]) (8.1.6)
# Collecting h11>=0.8 (from uvicorn->docarray[common]<0.30.0->finetuner[full])
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from ecdsa!=0.15->python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (1.16.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (2023.6.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.4.4->finetuner-commons==0.13.10->finetuner[full]) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi->docarray[common]<0.30.0->finetuner[full]) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full]) (1.3.0)
# Collecting safetensors (from timm->open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi->docarray[common]<0.30.0->finetuner[full]) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi->docarray[common]<0.30.0->finetuner[full]) (1.1.2)
# Building wheels for collected packages: finetuner, docarray
#   Building wheel for finetuner (pyproject.toml) ... done
#   Created wheel for finetuner: filename=finetuner-0.8.1-py3-none-any.whl size=39375 sha256=8c18c87ab94c688fcd5cba481d21d89185df735149780bc05756e96e3463be7e
#   Stored in directory: /root/.cache/pip/wheels/f7/bb/41/863d09fad887b582f402ae8f1ac7c2e1add5d43c8f2c721bbd
#   Building wheel for docarray (pyproject.toml) ... done
#   Created wheel for docarray: filename=docarray-0.21.1-py3-none-any.whl size=721987 sha256=61f05efcfd8eaf3dde8b417bf0898f08effd733f573f3e1d8ee4bfdab60fecb6
#   Stored in directory: /root/.cache/pip/wheels/06/f4/c7/9a43755a64ffaa3d7e0998f3848dfdd46edaf0d76da5db4dee
# Successfully built finetuner docarray
# Installing collected packages: tokenizers, sentencepiece, safetensors, trimesh, pathspec, onnx, lz4, humanfriendly, h11, ftfy, ecdsa, uvicorn, starlette, python-jose, huggingface-hub, finetuner-stubs, docker, coloredlogs, transformers, onnxruntime, jina-hubble-sdk, fastapi, docarray, timm, open-clip-torch, finetuner-commons, finetuner
# Successfully installed coloredlogs-15.0.1 docarray-0.21.1 docker-6.1.3 ecdsa-0.18.0 fastapi-0.100.1 finetuner-0.8.1 finetuner-commons-0.13.10 finetuner-stubs-0.13.10 ftfy-6.1.1 h11-0.14.0 huggingface-hub-0.16.4 humanfriendly-10.0 jina-hubble-sdk-0.33.1 lz4-4.3.2 onnx-1.14.0 onnxruntime-1.15.1 open-clip-torch-2.20.0 pathspec-0.11.2 python-jose-3.3.0 safetensors-0.3.1 sentencepiece-0.1.99 starlette-0.27.0 timm-0.9.2 tokenizers-0.12.1 transformers-4.20.1 trimesh-3.16.4 uvicorn-0.23.2
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-m6afd8yy
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-m6afd8yy
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (6.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.65.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.15.2+cu118)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->clip==1.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->clip==1.0) (16.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369498 sha256=8716a0e9bf78677e8ff96b8a8293e4be0ccc3f433ec3e65662b0b5c4b7602223
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w4a58097/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-1.0

# %%
# !pip show finetuner
# Out:
# Name: finetuner
# Version: 0.8.1
# Summary: Task-oriented finetuning for better embeddings on neural search.
# Home-page: https://github.com/jina-ai/finetuner/
# Author: Jina AI
# Author-email: hello@jina.ai
# License: Apache 2.0
# Location: /usr/local/lib/python3.8/site-packages
# Requires: docarray, finetuner-commons, finetuner-stubs
# Required-by:

# %%
# !gdown https://drive.google.com/uc?id=1i4UdF-DwiR00HUNFYsyXI5bmOqCdLLtJ
# !unzip ./dataset.zip
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1i4UdF-DwiR00HUNFYsyXI5bmOqCdLLtJ
# From (redirected): https://drive.google.com/uc?id=1i4UdF-DwiR00HUNFYsyXI5bmOqCdLLtJ&confirm=t&uuid=8f6cc23e-421e-439c-9370-e5aab33a2d2e
# To: /app/dataset.zip
# 100%|██████████████████████████████████████| 42.0M/42.0M [00:01<00:00, 30.7MB/s]
# Archive:  ./dataset.zip
#    creating: dataset/
#   inflating: __MACOSX/._dataset
#    creating: dataset/Neither/
#   inflating: __MACOSX/dataset/._Neither
#    creating: dataset/Ayaka/
#   inflating: __MACOSX/dataset/._Ayaka
#    creating: dataset/Albedo/
#   inflating: __MACOSX/dataset/._Albedo
#    creating: dataset/Hu Tao/
#   inflating: __MACOSX/dataset/._Hu Tao
#    creating: dataset/Kokomi/
#   inflating: __MACOSX/dataset/._Kokomi
#   inflating: dataset/Neither/63.jpg
#   inflating: __MACOSX/dataset/Neither/._63.jpg
#   inflating: dataset/Neither/77.jpg
#   inflating: __MACOSX/dataset/Neither/._77.jpg
#   inflating: dataset/Neither/88.jpg
#   inflating: __MACOSX/dataset/Neither/._88.jpg
#   inflating: dataset/Neither/89.jpg
#   inflating: __MACOSX/dataset/Neither/._89.jpg
#   inflating: dataset/Neither/76.jpg
#   inflating: __MACOSX/dataset/Neither/._76.jpg
#   inflating: dataset/Neither/62.jpg
#   inflating: __MACOSX/dataset/Neither/._62.jpg
#   inflating: dataset/Neither/74.jpg
#   inflating: __MACOSX/dataset/Neither/._74.jpg
#   inflating: dataset/Neither/60.jpg
#   inflating: __MACOSX/dataset/Neither/._60.jpg
#   inflating: dataset/Neither/48.jpg
#   inflating: __MACOSX/dataset/Neither/._48.jpg
#   inflating: dataset/Neither/49.jpg
#   inflating: dataset/Kokomi/40.jpg
#   inflating: __MACOSX/dataset/Kokomi/._40.jpg
#   inflating: dataset/Kokomi/54.jpg
#   inflating: __MACOSX/dataset/Kokomi/._54.jpg
#   inflating: dataset/Kokomi/6.jpg
#   inflating: __MACOSX/dataset/Kokomi/._6.jpg
#   inflating: dataset/Kokomi/78.jpg
#   inflating: __MACOSX/dataset/Kokomi/._78.jpg
#   inflating: dataset/Kokomi/2.jpg
#   inflating: __MACOSX/dataset/Kokomi/._2.jpg
#   inflating: dataset/Kokomi/50.jpg
#   inflating: __MACOSX/dataset/Kokomi/._50.jpg
#   inflating: dataset/Kokomi/44.jpg
#   inflating: __MACOSX/dataset/Kokomi/._44.jpg
#   inflating: dataset/Kokomi/93.jpg
#   inflating: __MACOSX/dataset/Kokomi/._93.jpg
#   inflating: dataset/Kokomi/87.jpg
#   inflating: __MACOSX/dataset/Kokomi/._87.jpg
#   inflating: dataset/Kokomi/86.jpg
#   inflating: __MACOSX/dataset/Kokomi/._86.jpg
#   inflating: dataset/Kokomi/92.jpg
#   inflating: __MACOSX/dataset/Kokomi/._92.jpg
#   inflating: dataset/Kokomi/45.jpg
#   inflating: __MACOSX/dataset/Kokomi/._45.jpg
#   inflating: dataset/Kokomi/3.jpg
#   inflating: __MACOSX/dataset/Kokomi/._3.jpg
#   inflating: dataset/Kokomi/51.jpg
#   inflating: __MACOSX/dataset/Kokomi/._51.jpg
#   inflating: dataset/Kokomi/79.jpg
#   inflating: __MACOSX/dataset/Kokomi/._79.jpg
#   inflating: dataset/Kokomi/47.jpg
#   inflating: __MACOSX/dataset/Kokomi/._47.jpg
#   inflating: dataset/Kokomi/53.jpg
#   inflating: __MACOSX/dataset/Kokomi/._53.jpg
#   inflating: dataset/Kokomi/1.jpg
#   inflating: __MACOSX/dataset/Kokomi/._1.jpg
#   inflating: dataset/Kokomi/84.jpg
#   inflating: __MACOSX/dataset/Kokomi/._84.jpg
#   inflating: dataset/Kokomi/90.jpg
#   inflating: __MACOSX/dataset/Kokomi/._90.jpg
#   inflating: dataset/Kokomi/91.jpg
#   inflating: __MACOSX/dataset/Kokomi/._91.jpg
#   inflating: dataset/Kokomi/85.jpg
#   inflating: __MACOSX/dataset/Kokomi/._85.jpg
#   inflating: dataset/Kokomi/52.jpg
#   inflating: __MACOSX/dataset/Kokomi/._52.jpg
#   inflating: dataset/Kokomi/46.jpg
#   inflating: __MACOSX/dataset/Kokomi/._46.jpg

# %% [markdown]
# ## Zero-Shot CLIP Retrieval
#
# Now we have downloaded the dataset in the `/content/dataset/` folder. We'll use `docarray` to build a search system, and use pre-trained `CLIP ViT-B/32` as the encoder to encode the images.
#
# We'll construct some text queries about the Gineshi characters, such as `Ayaka dancing`, `Hu Tao fighting`, `Albedo fly` etc, to see if the zero-shot CLIP works.

# %%
from docarray import Document, DocumentArray

da = DocumentArray.from_files('./dataset/*/*.*')

def assign_labels(d: Document):
    d.tags['finetuner_label'] = d.uri.split('/')[3]
    return d

da.apply(assign_labels, show_progress=True)
# shuffle and train-test-split to 50-50
da = da.shuffle()
train_da = da[:250]
test_da = da[250:]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
test_da[0]
# Out:
# 📄 Document: b407f114de29af143012a78ee2da59e4
# ╭─────────────────────┬────────────────────────────────────────────────────────╮
# │ Attribute           │ Value                                                  │
# ├─────────────────────┼────────────────────────────────────────────────────────┤
# │ mime_type           │ image/jpeg                                             │
# │ uri                 │ ./dataset/Hu Tao/64.jpg                                │
# │ tags                │ {'finetuner_label': '64.jpg'}                          │
# ╰─────────────────────┴────────────────────────────────────────────────────────╯

# %%
import torch
import clip
from PIL import Image

device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

def preprocess_and_encode_image(d: Document):
    """Preprocess image and extract embeddings from CLIP image encoder"""
    d.tensor = preprocess(Image.open(d.uri)).unsqueeze(0).to(device)
    d.embedding = model.encode_image(d.tensor).cpu().detach().numpy().squeeze()
    d.pop('tensor')
    return d

def preprocess_and_encode_text(d: Document):
    """Preprocess image and extract embeddings from CLIP text encoder"""
    d.tensor = clip.tokenize(d.text).to(device)
    d.embedding = model.encode_text(d.tensor).cpu().detach().numpy().squeeze()
    d.pop('tensor')
    return d
# Out:
# 100%|███████████████████████████████████████| 338M/338M [00:11<00:00, 30.6MiB/s]

# %% [markdown]
# Now we have our data and pre-processing functions ready. The next steps are:
#
# 1. Apply feature extraction on all the `test_da`.
#
# 2. Construct some text queries to find similar image Documents.

# %%
# embed all test documents
test_da.apply(preprocess_and_encode_image, show_progress=True)
# Out:
# /usr/local/lib/python3.8/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────── Documents Summary ─────────────────────────────╮
# │                                                                            │
# │   Type                   DocumentArrayInMemory                             │
# │   Length                 250                                               │
# │   Homogenous Documents   True                                              │
# │   Common Attributes      ('id', 'mime_type', 'uri', 'tags', 'embedding')   │
# │   Multimodal dataclass   False                                             │
# │                                                                            │
# ╰────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────── Attributes Summary ───────────────────────╮
# │                                                                 │
# │   Attribute   Data type      #Unique values   Has empty value   │
# │  ─────────────────────────────────────────────────────────────  │
# │   embedding   ('ndarray',)   250              False             │
# │   id          ('str',)       250              False             │
# │   mime_type   ('str',)       1                False             │
# │   tags        ('dict',)      250              False             │
# │   uri         ('str',)       250              False             │
# │                                                                 │
# ╰─────────────────────────────────────────────────────────────────╯

# %%
# embed a user query
query = 'Hu Tao fighting'
query_docs = DocumentArray([Document(content=query)])
query_docs.apply(preprocess_and_encode_text)
# find top 5 matches
query_docs.match(test_da, metric='cosine', limit=5)
# plot matches
for idx, match in enumerate(query_docs[0].matches):
    print(f'The matched document agains query \033[1m{query}\033[0m at position \033[1m{idx}\033[0m is \033[1m{match.tags["finetuner_label"]}\033[0m')
    match.display()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# The matched document agains query Hu Tao fighting at position 0 is 38.jpg
# The matched document agains query Hu Tao fighting at position 1 is 81.jpg
# The matched document agains query Hu Tao fighting at position 2 is 23.jpg
# The matched document agains query Hu Tao fighting at position 3 is 30.jpg
# The matched document agains query Hu Tao fighting at position 4 is 19.jpg

# %%
# embed a user query
query = 'Ayaka dancing'
query_docs = DocumentArray([Document(content=query)])
query_docs.apply(preprocess_and_encode_text)
# find top 5 matches
query_docs.match(test_da, metric='cosine', limit=5)
# plot matches
for idx, match in enumerate(query_docs[0].matches):
    print(f'The matched document agains query \033[1m{query}\033[0m at position \033[1m{idx}\033[0m is \033[1m{match.tags["finetuner_label"]}\033[0m')
    match.display()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# The matched document agains query Ayaka dancing at position 0 is 11.jpg
# The matched document agains query Ayaka dancing at position 1 is 9.jpg
# The matched document agains query Ayaka dancing at position 2 is 37.jpg
# The matched document agains query Ayaka dancing at position 3 is 78.jpg
# The matched document agains query Ayaka dancing at position 4 is 88.jpg

# %%
# embed a user query
query = 'Albedo flying'
query_docs = DocumentArray([Document(content=query)])
query_docs.apply(preprocess_and_encode_text)
# find top 5 matches
query_docs.match(test_da, metric='cosine', limit=5)
# plot matches
for idx, match in enumerate(query_docs[0].matches):
    print(f'The matched document agains query \033[1m{query}\033[0m at position \033[1m{idx}\033[0m is \033[1m{match.tags["finetuner_label"]}\033[0m')
    match.display()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# The matched document agains query Albedo flying at position 0 is 10.jpg
# The matched document agains query Albedo flying at position 1 is 57.jpg
# The matched document agains query Albedo flying at position 2 is 63.jpg
# The matched document agains query Albedo flying at position 3 is 53.jpg
# The matched document agains query Albedo flying at position 4 is 94.jpg

# %% [markdown]
# As you can see we created three user queries:
#
# 1. `Hu Tao Fighting`: In the top five results we only got one match. While thre matches are related to Ayaka.
# 2. `Ayaka dancing`: In this case, zero-shot CLIP returns good results. One of the reasons is that in Genshin Impact [Ayaka's cutscene](https://youtu.be/g-o-l8j6d8Q) is dancing, this is rare for other characters.
# 3. `Albedo flying`: This is a hard query, and as expected, none of the returned matches are related to Albedo, while most of the images are indeed related to flying.
#
# So it's ok-ish but now, let's fine-tune CLIP to see if we can get better results.
#
# ## CLIP Fine-tuning
#
# Fine-tuning the CLIP model is not easy. It involves two models: the `clip image encoder` and `clip text encoder` and optimize the clip loss jointly. Luckily, the package `finetuner` makes it easy!
#
# The GitHub repo: https://github.com/jina-ai/finetuner
#
# The documentation: https://finetuner.jina.ai/
#
# In short, `finetuner` receives a `DocumentArray` as training data and ouputs an `artifact`. For the case of CLIP, the `artifact` contains 2

# %%
# !pip install ipywidgets

import finetuner
# finetuner.notebook_login(force=True)
finetuner.login(interactive=False)
# Out:
# Your browser is going to open the login page.
# If this fails please open the following link: https://jina-ai.us.auth0.com/authorize?response_mode=form_post&nonce=a5d4315f47577b6995d0461ff0147018&state=a5d4315f47577b6995d0461ff0147018&scope=profile+openid+email&redirect_uri=https%3A%2F%2Fapi.hubble.jina.ai%2Fv2%2Foidc%2FidpAuthorized&client_id=7pXAUAtiRqruNd6KJ6U3Zd9uhk5oLqZA&response_type=code&code_challenge=bOlUaMQSoNJfdZ1Pw39Qq2ZgJytTsa0Dni1c8n5ELcI&code_challenge_method=S256
# 🔐 Successfully logged in to Jina AI as wjp1999119 (username: wjp1999119)!

# %% [markdown]
# Now we need to prepare training data for CLIP. As you might already know CLIP was trained on pairs of textual data and image data, it can be organized as a `Document` with two `chunks` inside. For example:
#
# ```python
# train_da = DocumentArray([
#     Document(
#         chunks=[
#             Document(
#                 content='pencil skirt slim fit available for sell',
#                 modality='text',
#             ),
#             Document(
#                 uri='https://...skirt-1.png',
#                 modality='image',
#             ),
#         ],
#     ),
#     ...# more documents
# ])
# ```
#
# We just need to clean up our `train_da` to adopt the above form. It should be noted that if an image is stored locally, you can convert it to a `tensor` object:

# %%
pairs = DocumentArray() # initialize a DocumentArray as final training data.

prompt = 'This is a photo of '
for doc in train_da:
    pair = Document()
    img_chunk = doc.load_uri_to_image_tensor(224, 224)
    img_chunk.modality = 'image'
    txt_chunk = Document(content=prompt + doc.tags['finetuner_label'])
    txt_chunk.modality = 'text'
    pair.chunks.extend([img_chunk, txt_chunk])
    # add pair to pairs
    pairs.append(pair)

# Lets see the first item of the pairs
pairs[0]
# Out:
# 📄 Document: 94dacfbe4288f4498e332409b4c9acee
# └── 💠 Chunks
#     ├── 📄 Document: fa4adc48763eddee91041468487ba377
#     │   ╭────────────┬─────────────────────────────────────────────────────────────────╮
#     │   │ Attribute  │ Value                                                           │
#     │   ├────────────┼─────────────────────────────────────────────────────────────────┤
#     │   │ tensor     │ <class 'numpy.ndarray'> in shape (224, 224, 3), dtype: uint8    │
#     │   │ mime_type  │ image/jpeg                                                      │
#     │   │ uri        │ ./dataset/Hu Tao/78.jpg                                         │
#     │   │ tags       │ {'finetuner_label': '78.jpg'}                                   │
#     │   │ modality   │ image                                                           │
#     │   ╰────────────┴─────────────────────────────────────────────────────────────────╯
#     └── 📄 Document: ee8fb61f1c1c11b868ba873d632b52da
#         ╭───────────────────────┬──────────────────────────────────────────────────────╮
#         │ Attribute             │ Value                                                │
#         ├───────────────────────┼──────────────────────────────────────────────────────┤
#         │ text                  │ This is a photo of 78.jpg                            │
#         │ modality              │ text                                                 │
#         ╰───────────────────────┴──────────────────────────────────────────────────────╯

# %%
len(pairs)
# Out:
# 250

# %% [markdown]
# As you can see above, now we have a list of pairs of `Document`s which forms a `DocumentArray`, in each pair, we have:
#
# 1. An `image chunk`: containing the image `tensor` object and `modality='image'`
# 2. A `text_chunk`: containing the `text` which is identical to the prompt and the name of the character (e.g. `this is a photo of Ayaka`) and `modality='text'`.
#
# Now, we are ready to train our model.
#
# Before training, something basic concepts to be aware of is that:
#
# 1. `experiment` and `run`: represent how your different settings are organized: an experiment contains multiple runs with different hyper-parameter settings for your fine-tuning job.
# 2. Once you call `finetuner.fit` function, it will schedule CPU/GPU/memory and all computation resources in the cloud (for free!).

# %%
run = finetuner.fit(
    model='openai/clip-vit-base-patch32', # fine-tune CLIP
    train_data=pairs,
    learning_rate=1e-5,
    loss='CLIPLoss',
)
# Out:
#   Pushing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250/250 • 42 QPS • 0:00:00 • 25.8 MB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# Model fine-tuning might take some time. You can trace your job with:

# %%
for entry in run.stream_logs():
    print(entry)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [11:31:11] INFO     Starting finetuner training run ...                                                  __main__.py:350
# DEBUG    Found Jina AI Cloud authentication token                                             __main__.py:362
# DEBUG    Running in online mode                                                               __main__.py:363
# INFO     Reading config ...                                                                   __main__.py:370
# DEBUG    Reading config from stream                                                           __main__.py:382
# INFO     Parsing config ...                                                                   __main__.py:385
# INFO     Config loaded 📜                                                                     __main__.py:389
# INFO     Run name: keen-payne                                                                 __main__.py:391
# INFO     Experiment name: default                                                             __main__.py:392
# DEBUG    Device set to [cuda]                                                                 __main__.py:395
# DEBUG    Artifact ID set to 64c79b5fa2af8b56e6fc7c42                                          __main__.py:141
# DEBUG    Artifact ID for metrics set to 64c79b5fa2af8b56e6fc7c43                              __main__.py:144
# DEBUG    Artifact ID for example results set to 64c79b60a2af8b56e6fc7c44                      __main__.py:147
# INFO     Building the tuner components ...                                                    __main__.py:161
# INFO     Building models ...                                                                    tuning.py:326
# DEBUG    Model name: openai/clip-vit-base-patch32                                               tuning.py:328
# DEBUG    Model options: {}                                                                      tuning.py:329
# Downloading:   0%|          | 0.00/4.09k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 4.09k/4.09k [00:00<00:00, 19.5MB/s]
# ping
# 2023-07-31 11:31:31.038043
# Downloading:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 568/568 [00:00<00:00, 4.81MB/s]
# Downloading:   0%|          | 0.00/842k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 842k/842k [00:00<00:00, 41.6MB/s]
# Downloading:   0%|          | 0.00/512k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 512k/512k [00:00<00:00, 45.8MB/s]
# Downloading:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# Downloading:  65%|██████▌   | 1.38M/2.12M [00:00<00:00, 14.5MB/s]
# Downloading: 100%|██████████| 2.12M/2.12M [00:00<00:00, 19.8MB/s]
# Downloading:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 389/389 [00:00<00:00, 3.67MB/s]
# Downloading:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 316/316 [00:00<00:00, 2.76MB/s]
# [11:31:27] INFO     Loading the training data ...                                                          tuning.py:158
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# 🔐 You are logged in to Jina AI as wjp1999119 (username: wjp1999119). To log out, use jina auth logout.
# Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250/250 • 164 QPS • 0:00:00 • 25.8 MB
# [11:31:32] DEBUG    # training samples: 250                                                                tuning.py:171
# INFO     Building loss ...                                                                      tuning.py:431
# DEBUG    Loss name: CLIPLoss                                                                    tuning.py:432
# DEBUG    Loss options: {}                                                                       tuning.py:433
# [11:31:33] DEBUG    Saving initial state of the model                                                    batchsize.py:86
# DEBUG    Testing batch size of 4                                                             batchsize.py:122
# [11:31:34] DEBUG    Testing batch size of 8                                                             batchsize.py:122
# [11:31:35] DEBUG    Testing batch size of 16                                                            batchsize.py:122
# DEBUG    Testing batch size of 32                                                            batchsize.py:122
# ping
# 2023-07-31 11:31:46.038474
# [11:31:36] DEBUG    Testing batch size of 64                                                            batchsize.py:122
# Traceback (most recent call last):
# File "/usr/local/lib/python3.8/multiprocessing/queues.py", line 245, in _feed
# send_bytes(obj)
# File "/usr/local/lib/python3.8/multiprocessing/connection.py", line 200, in send_bytes
# self._send_bytes(m[offset:offset + size])
# File "/usr/local/lib/python3.8/multiprocessing/connection.py", line 411, in _send_bytes
# self._send(header + buf)
# File "/usr/local/lib/python3.8/multiprocessing/connection.py", line 368, in _send
# n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# DEBUG    Testing batch size of 128                                                           batchsize.py:122
# [11:31:37] DEBUG    Testing batch size of 250                                                           batchsize.py:122
# [11:31:39] DEBUG    Batch_size adjusted from 4 to 250                                                    batchsize.py:91
# DEBUG    Restoring initial state of the model                                                 batchsize.py:93
# INFO     Building loss ...                                                                      tuning.py:431
# DEBUG    Loss name: CLIPLoss                                                                    tuning.py:432
# DEBUG    Loss options: {}                                                                       tuning.py:433
# INFO     Building optimizer ...                                                                 tuning.py:538
# DEBUG    Optimizer name: Adam                                                                   tuning.py:539
# DEBUG    Optimizer options: {'lr': 1e-05}                                                       tuning.py:540
# INFO     Model, data, callbacks, loss, miner and optimizer built successfully 🔥              __main__.py:165
# INFO     Finetuning ...                                                                       __main__.py:170
# Training [5/5] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 0:00:00 0:00:01 • loss: 5.380
# [11:31:46] INFO     Done ✨                                                                              __main__.py:192
# DEBUG    Finetuning took 0 days, 0 hours 0 minutes and 6 seconds                              __main__.py:194
# INFO     Building the artifact ...                                                            __main__.py:231
# INFO     Pushing artifact to Jina AI Cloud ...                                                __main__.py:260
# ping
# 2023-07-31 11:32:01.039086
# ping
# 2023-07-31 11:32:16.039381
# ping
# 2023-07-31 11:32:31.038965
# ping
# 2023-07-31 11:32:46.038763
# ping
# 2023-07-31 11:33:01.038808
# ping
# 2023-07-31 11:33:16.038973
# ping
# 2023-07-31 11:33:31.038923
# [11:33:25] INFO     Artifact pushed under ID '64c79b5fa2af8b56e6fc7c42'                                  __main__.py:266
# DEBUG    Artifact size is 535.388 MB                                                          __main__.py:268
# INFO     Finished 🚀                                                                          __main__.py:415
# time="2023-07-31T11:33:27.487Z" level=info msg="sub-process exited" argo=true error="<nil>"

# %%
# save the artifact
artifact = run.save_artifact('./')
# Out:
# ⠦ Downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 559939584/561395442 • 16558318 QPS • 0:00:01 • 561.4 MB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
clip_text_encoder = finetuner.get_model(artifact=artifact, select_model='clip-text')
clip_image_encoder = finetuner.get_model(artifact=artifact, select_model='clip-vision')
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 568/568 [00:00<00:00, 2.56MB/s]
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4.09k/4.09k [00:00<00:00, 8.74MB/s]
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 842k/842k [00:00<00:00, 9.75MB/s]
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 512k/512k [00:00<00:00, 5.55MB/s]
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2.12M/2.12M [00:00<00:00, 18.8MB/s]
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 389/389 [00:00<00:00, 2.19MB/s]
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 316/316 [00:00<00:00, 1.58MB/s]

# %%
finetuner.encode(model=clip_image_encoder, data=test_da)
# Out:
# Batching documents ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:03
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────── Documents Summary ─────────────────────────────╮
# │                                                                            │
# │   Type                   DocumentArrayInMemory                             │
# │   Length                 250                                               │
# │   Homogenous Documents   True                                              │
# │   Common Attributes      ('id', 'mime_type', 'uri', 'tags', 'embedding')   │
# │   Multimodal dataclass   False                                             │
# │                                                                            │
# ╰────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────── Attributes Summary ───────────────────────╮
# │                                                                 │
# │   Attribute   Data type      #Unique values   Has empty value   │
# │  ─────────────────────────────────────────────────────────────  │
# │   embedding   ('ndarray',)   250              False             │
# │   id          ('str',)       250              False             │
# │   mime_type   ('str',)       1                False             │
# │   tags        ('dict',)      250              False             │
# │   uri         ('str',)       250              False             │
# │                                                                 │
# ╰─────────────────────────────────────────────────────────────────╯

# %%
# embed a user query, in this case, the query keywords is "Hu Tao fighting"
query = 'Hu Tao flying'
query_docs = DocumentArray([Document(content=query)])

finetuner.encode(model=clip_text_encoder, data=query_docs)
# find top 5 matches
query_docs.match(test_da, metric='cosine', limit=5)
# plot matches
for idx, match in enumerate(query_docs[0].matches):
    print(f'The matched document again query \033[1m{query}\033[0m at position \033[1m{idx}\033[0m is \033[1m{match.tags["finetuner_label"]}\033[0m')
    match.display()
# Out:
# Batching documents ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# The matched document again query Hu Tao flying at position 0 is 5.jpg
# The matched document again query Hu Tao flying at position 1 is 3.jpg
# The matched document again query Hu Tao flying at position 2 is 46.jpg
# The matched document again query Hu Tao flying at position 3 is 63.jpg
# The matched document again query Hu Tao flying at position 4 is 10.jpg

# %%
# embed a user query.
query = 'Ayaka dancing'
query_docs = DocumentArray([Document(content=query)])

finetuner.encode(model=clip_text_encoder, data=query_docs)
# find top 5 matches
query_docs.match(test_da, metric='cosine', limit=5)
# plot matches
for idx, match in enumerate(query_docs[0].matches):
    print(f'The matched document again query \033[1m{query}\033[0m at position \033[1m{idx}\033[0m is \033[1m{match.tags["finetuner_label"]}\033[0m')
    match.display()
# Out:
# Batching documents ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# The matched document again query Ayaka dancing at position 0 is 81.jpg
# The matched document again query Ayaka dancing at position 1 is 61.jpg
# The matched document again query Ayaka dancing at position 2 is 21.jpg
# The matched document again query Ayaka dancing at position 3 is 84.jpg
# The matched document again query Ayaka dancing at position 4 is 41.jpg

# %%
# embed a user query.
query = 'Albedo flying'
query_docs = DocumentArray([Document(content=query)])

finetuner.encode(model=clip_text_encoder, data=query_docs)
# find top 5 matches
query_docs.match(test_da, metric='cosine', limit=5)
# plot matches
for idx, match in enumerate(query_docs[0].matches):
    print(f'The matched document again query \033[1m{query}\033[0m at position \033[1m{idx}\033[0m is \033[1m{match.tags["finetuner_label"]}\033[0m')
    match.display()
# Out:
# Batching documents ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# The matched document again query Albedo flying at position 0 is 46.jpg
# The matched document again query Albedo flying at position 1 is 69.jpg
# The matched document again query Albedo flying at position 2 is 63.jpg
# The matched document again query Albedo flying at position 3 is 40.jpg
# The matched document again query Albedo flying at position 4 is 3.jpg

# %% [markdown]
# Let's see the results!
#
# 1. `Hu Tao Fighting`: In top 5 results we only got 2 matches. Compared with before, minor improvements.
# 2. `Ayaka dancing`: In this case, zero-shot CLIP returns nice results. Compared with before, all matched results are Ayaka and also related to her dancing scene!
# 3. `Albedo flying`: This is a hard query, previously, we got 0 matches. Now, all images are Albedo images, and some of them are flying albedo!
#
# End thoughts:
#
# 1. Fine-tuning CLIP with only 250 samples can already improve CLIP on retrieval a lot!
